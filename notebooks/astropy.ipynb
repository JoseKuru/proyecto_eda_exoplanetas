# %%
from astropy.table import Table
dat = Table.read('kplr010000941-2009166043257_llc.fits', format='fits')
df = dat.to_pandas()
# Out:
# /home/jose/.local/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df
# Out:
#             TIME  TIMECORR  CADENCENO      SAP_FLUX  SAP_FLUX_ERR  \
# 0     131.512427  0.001433       1105  49244.015625      6.692365
# 1     131.532862  0.001434       1106  49238.148438      6.692475
# 2     131.553296  0.001435       1107  49247.695312      6.692393
# 3     131.573730  0.001436       1108  49260.718750      6.693181
# 4     131.594164  0.001436       1109  49255.089844      6.692954
# ...          ...       ...        ...           ...           ...
# 1634  164.901906  0.002415       2739  50606.855469      6.754342
# 1635  164.922340  0.002416       2740  50605.859375      6.754455
# 1636  164.942774  0.002416       2741  50611.406250      6.754709
# 1637  164.963208  0.002417       2742  50600.480469      6.754248
# 1638  164.983642  0.002417       2743  50619.878906      6.755054
#
#           SAP_BKG  SAP_BKG_ERR   PDCSAP_FLUX  PDCSAP_FLUX_ERR  SAP_QUALITY  \
# 0     1510.700317     0.503156  52877.078125         7.124573            0
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='TIME', y='SAP_FLUX', color='green')
# Out:
# <AxesSubplot:xlabel='TIME', ylabel='SAP_FLUX'>
