# %%
from sqlalchemy import create_engine
import pandas as pd
# Out:
# /home/jose/.local/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
engine = create_engine('mysql+pymysql://49078469b:josecarlosbatistarivero@54.87.229.244:25001/49078469b_ds_april_2021_db')

# %%
df = pd.read_csv('../data/phl_exoplanet_catalog_cleaned.csv')
df.head()
# Out:
#        Nombre Metodo_deteccion      Radio  Periodo_orbital  \
# 0    11 Com b  Radial Velocity  12.082709        326.03000
# 1    11 UMi b  Radial Velocity  12.229641        516.21997
# 2    14 And b  Radial Velocity  12.848516        185.84000
# 3    14 Her b  Radial Velocity  12.865261       1773.40000
# 4  16 Cyg B b  Radial Velocity  13.421749        798.50000
#
#    Indice_similitud_tierra  Distancia_estrella  Distancia_tierra  \
# 0                 0.083813            0.406263             93.37
# 1                 0.082414            0.470827            125.72
# 2                 0.081917            0.254601             75.59
# 3                 0.145241            0.960294             17.94
# 4                 0.368627            0.626930             21.15
#
#    Radio_estrella  Ascension_recta  Declinacion
# 0           19.00        12.345286    17.792868
# 1           29.79        15.284970    71.823898
# 2           11.00        23.521506    39.236198
# ...

# %%
df.to_sql('jose_carlos_batista_rivero', con=engine, index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                     self.dialect.do_execute(
# -> 1771                         cursor, statement, parameters, context
#    1772                     )
#
# ~/.local/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# ~/.local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...
